# %% [markdown]
# # Richmond Fed
#
# - Richmond Manufacturing PMI
# - Richmond Services PMI

# %%
import os
import pandas as pd

# path for the folder "project"
path = "C:\\Users\\pedro\\OneDrive\\NYU\\CSS\\II. Data Skills\\project"
os.chdir(path)

# %% [markdown]
# ## Richmond Manufacturing PMI
#
# Importing the .xlsx file from their website

# %%
rich_mpmi = pd.read_excel("https://www.richmondfed.org/-/media/RichmondFedOrg/research/regional_economy/surveys_of_business_conditions/manufacturing/data/mfg_historicaldata.xlsx")
rich_mpmi.head()
# Out:
#         date  nsa_mfg_commentsTopics  nsa_mfg_ship_c  nsa_mfg_new_orders_c  \
# 0 1993-11-01                     NaN               4                     9
# 1 1993-12-01                     NaN              13                     9
# 2 1994-01-01                     NaN              13                    19
# 3 1994-02-01                     NaN               2                     9
# 4 1994-03-01                     NaN              37                    30
#
#    nsa_mfg_bk_logs_c  nsa_mfg_cap_util_c  nsa_mfg_vend_lead_c  nsa_mfg_emp_c  \
# 0                 -4                 NaN                  NaN              3
# 1                 -3                 NaN                  NaN             -1
# 2                  9                 NaN                  NaN             -3
# 3                  3                 NaN                  NaN             -9
# 4                 19                 NaN                  NaN              2
#
# ...

# %%
# dropping irrelevant columns:
rich_mpmi = rich_mpmi.drop(columns = "nsa_mfg_commentsTopics")

# melting:
rich_mpmi = (
    rich_mpmi
    .melt(id_vars="date",var_name = "series_id")
    [["series_id","date","value"]]
)

rich_mpmi.head()
# Out:
#         series_id       date  value
# 0  nsa_mfg_ship_c 1993-11-01    4.0
# 1  nsa_mfg_ship_c 1993-12-01   13.0
# 2  nsa_mfg_ship_c 1994-01-01   13.0
# 3  nsa_mfg_ship_c 1994-02-01    2.0
# 4  nsa_mfg_ship_c 1994-03-01   37.0

# %% [markdown]
# Building metadata:

# %%
rich_mpmi_dict = [
    ['nsa_mfg_ship_c', "Shipments", "Current", "Diffusion Index", "NSA"],
    ['nsa_mfg_new_orders_c', "New Orders", "Current", "Diffusion Index", "NSA"],
    ['nsa_mfg_bk_logs_c', "Order Back Logs", "Current", "Diffusion Index", "NSA"],
    ['nsa_mfg_cap_util_c', "Capacity Utilization", "Current", "Diffusion Index", "NSA"],
    ['nsa_mfg_vend_lead_c', "Vendor Lead Time", "Current", "Diffusion Index", "NSA"],
    ['nsa_mfg_emp_c', "Employment", "Current", "Diffusion Index", "NSA"],
    ['nsa_mfg_workwk_c', "Average Workweek", "Current", "Diffusion Index", "NSA"],
    ['nsa_mfg_wage_c', "Average Wage", "Current", "Diffusion Index", "NSA"],
    ['nsa_mfg_fd_gds_inv_c', "Finished Goods Inventory", "Current", "Diffusion Index", "NSA"],
    ['nsa_mfg_raw_mats_inv_c', "Raw Materials Inventory", "Current", "Diffusion Index", "NSA"],
    ['nsa_mfg_pct_chg_prcs_recd_c', "Prices Received", "Current", "Percent Change", "NSA"],
    ['nsa_mfg_pct_chg_prcs_pd_c', "Prices Paid", "Current", "Percent Change", "NSA"],
    ['sa_mfg_composite', "Composite", "Current", "Diffusion Index", "SA"],
    ['sa_mfg_ship_c', "Shipments", "Current", "Diffusion Index", "SA"],
    ['sa_mfg_new_orders_c', "New Orders", "Current", "Diffusion Index", "SA"],
    ['sa_mfg_bk_logs_c', "Order Back Logs", "Current", "Diffusion Index", "SA"],
    ['sa_mfg_cap_util_c', "Capacity Utilization", "Current", "Diffusion Index", "SA"],
    ['sa_mfg_vend_lead_c', "Vendor Lead Time", "Current", "Diffusion Index", "SA"],
    ['sa_mfg_emp_c', "Employment", "Current", "Diffusion Index", "SA"],
    ['sa_mfg_workwk_c', "Average Workweek", "Current", "Diffusion Index", "SA"],
    ['sa_mfg_wage_c', "Average Wage", "Current", "Diffusion Index", "SA"],
    ['sa_mfg_fd_gds_inv_c', "Finished Goods Inventory", "Current", "Diffusion Index", "SA"],
    ['sa_mfg_raw_mats_inv_c', "Raw Materials Inventory", "Current", "Diffusion Index", "SA"],
    ['sa_mfg_pct_chg_prcs_recd_c', "Prices Received", "Current", "Percent Change", "SA"],
    ['sa_mfg_pct_chg_prcs_pd_c', "Prices Paid", "Current", "Percent Change", "SA"],
    ['nsa_mfg_ship_e', "Shipments", "Future", "Diffusion Index", "NSA"],
    ['nsa_mfg_new_orders_e', "New Orders", "Future", "Diffusion Index", "NSA"],
    ['nsa_mfg_bk_logs_e', "Order Back Logs", "Future", "Diffusion Index", "NSA"],
    ['nsa_mfg_cap_util_e', "Capacity Utilization", "Future", "Diffusion Index", "NSA"],
    ['nsa_mfg_vend_lead_e', "Vendor Lead Time", "Future", "Diffusion Index", "NSA"],
    ['nsa_mfg_emp_e', "Employment", "Future", "Diffusion Index", "NSA"],
    ['nsa_mfg_workwk_e', "Average Workweek", "Future", "Diffusion Index", "NSA"],
    ['nsa_mfg_wage_e', "Average Wage", "Future", "Diffusion Index", "NSA"],
    ['nsa_mfg_capital_expnd_e', "Capital Expenditures", "Future", "Diffusion Index", "NSA"],
    ['nsa_mfg_pct_chg_prcs_recd_e', "Prices Received", "Future", "Percent Change", "NSA"],
    ['nsa_mfg_pct_chg_prcs_pd_e', "Prices Paid", "Future", "Percent Change", "NSA"],
    ['sa_mfg_ship_e', "Shipments", "Future", "Diffusion Index", "SA"],
    ['sa_mfg_new_orders_e', "New Orders", "Future", "Diffusion Index", "SA"],
    ['sa_mfg_bk_logs_e', "Order Back Logs", "Future", "Diffusion Index", "SA"],
    ['sa_mfg_cap_util_e', "Capacity Utilization", "Future", "Diffusion Index", "SA"],
    ['sa_mfg_vend_lead_e', "Vendor Lead Time", "Future", "Diffusion Index", "SA"],
    ['sa_mfg_emp_e', "Employment", "Future", "Diffusion Index", "SA"],
    ['sa_mfg_workwk_e', "Average Workweek", "Future", "Diffusion Index", "SA"],
    ['sa_mfg_wage_e', "Average Wage", "Future", "Diffusion Index", "SA"],
    ['sa_mfg_capital_expnd_e', "Capital Expenditures", "Future", "Diffusion Index", "SA"],
    ['sa_mfg_pct_chg_prcs_recd_e', "Prices Received", "Future", "Percent Change", "SA"],
    ['sa_mfg_pct_chg_prcs_pd_e', "Prices Paid", "Future", "Percent Change", "SA"],
    ['sa_mfg_local_bus_cond_c', "Local Business Conditions", "Current", "Diffusion Index", "SA"],
    ['sa_mfg_nec_skls_avail_e', "Availability of Skills Needed", "Future", "Diffusion Index", "SA"],
    ['sa_mfg_local_bus_cond_e', "Local Business Conditions", "Future", "Diffusion Index", "SA"],
    ['sa_mfg_nec_skls_avail_c', "Availability of Skills Needed", "Current", "Diffusion Index", "SA"],
    ['sa_mfg_equip_sftw_expnd_e', "Equipment and Software Expenditures", "Future", "Diffusion Index", "SA"],
    ['sa_mfg_bus_svcs_expnd_e', "Business Services Expenditures", "Future", "Diffusion Index", "SA"],
    ['sa_mfg_equip_sftw_expnd_c', "Equipment and Software Expenditures", "Current", "Diffusion Index", "SA"],
    ['sa_mfg_capital_expnd_c', "Capital Expenditures", "Current", "Diffusion Index", "SA"],
    ['sa_mfg_bus_svcs_expnd_c', "Business Services Expenditures", "Current", "Diffusion Index", "SA"],
    ['sa_mfg_fd_gds_inv_e', "Finished Goods Inventory", "Future", "Diffusion Index", "SA"],
    ['sa_mfg_raw_mats_inv_e', "Raw Materials Inventory", "Future", "Diffusion Index", "SA"],
    ['nsa_mfg_nec_skls_avail_e', "Availability of Skills Needed", "Future", "Diffusion Index", "NSA"],
    ['nsa_mfg_equip_sftw_expnd_e', "Equipment and Software Expenditures", "Future", "Diffusion Index", "NSA"],
    ['nsa_mfg_bus_svcs_expnd_e', "Business Services Expenditures", "Future", "Diffusion Index", "NSA"],
    ['nsa_mfg_local_bus_cond_c', "Local Business Conditions", "Current", "Diffusion Index", "NSA"],
    ['nsa_mfg_nec_skls_avail_c', "Availability of Skills Needed", "Current", "Diffusion Index", "NSA"],
    ['nsa_mfg_equip_sftw_expnd_c', "Equipment and Software Expenditures", "Current", "Diffusion Index", "NSA"],
    ['nsa_mfg_local_bus_cond_e', "Local Business Conditions", "Future", "Diffusion Index", "NSA"],
    ['nsa_mfg_capital_expnd_c', "Capital Expenditures", "Current", "Diffusion Index", "NSA"],
    ['nsa_mfg_bus_svcs_expnd_c', "Business Services Expenditures", "Current", "Diffusion Index", "NSA"],
    ['nsa_mfg_fd_gds_inv_e', "Finished Goods Inventory", "Future", "Diffusion Index", "NSA"],
    ['nsa_mfg_raw_mats_inv_e', "Raw Materials Inventory", "Future", "Diffusion Index", "NSA"]
]

rich_mpmi_dict = pd.DataFrame(data=rich_mpmi_dict,
                              columns = ["series_id","item_name","state","data_type","seasonal"])

# %%
rich_mpmi_dict.head()
# Out:
#               series_id             item_name    state        data_type  \
# 0        nsa_mfg_ship_c             Shipments  Current  Diffusion Index
# 1  nsa_mfg_new_orders_c            New Orders  Current  Diffusion Index
# 2     nsa_mfg_bk_logs_c       Order Back Logs  Current  Diffusion Index
# 3    nsa_mfg_cap_util_c  Capacity Utilization  Current  Diffusion Index
# 4   nsa_mfg_vend_lead_c      Vendor Lead Time  Current  Diffusion Index
#
#   seasonal
# 0      NSA
# 1      NSA
# 2      NSA
# 3      NSA
# 4      NSA

# %% [markdown]
# Saving Files:

# %%
rich_mpmi.to_parquet("data\\business_surveys\\data_richmond_fed_mpmi.parquet")
rich_mpmi_dict.to_parquet("data\\business_surveys\\dict_richmond_fed_mpmi.parquet")
